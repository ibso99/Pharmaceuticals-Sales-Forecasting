# %% [markdown]
# # Outline
# - Importing Necessary Modules
#
# - Instantiating the LSTM Model
#
# - Running the Model Pipeline

# %%
import sys
sys.path.append('../scripts')

# %%
from LSTM_trainer import LSTMSalesModel

# %%
# Inistantiating the LSTM model class
data_path = "C:/Users/ibsan/Desktop/TenX/week-4/Data/store_train_clean_data.csv"
model = LSTMSalesModel(data_path)

# %%
# Running the pipeline
model.run_pipeline(save_path='C:/Users/ibsan/Desktop/TenX/week-4/saved_models.h5')
# Out:
# ADF Statistic: -18.707520084040386
# p-value: 2.0354748948272903e-30
# Critical Value (1%): -3.4303579087619824
# Critical Value (5%): -2.8615434955827523
# Critical Value (10%): -2.5667718605704786
# c:\Users\ibsan\Desktop\TenX\week-4\week-4\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 20674/20674 ━━━━━━━━━━━━━━━━━━━━ 53s 2ms/step - loss: 0.0788 - val_loss: 0.0778
# Epoch 2/50
# 20674/20674 ━━━━━━━━━━━━━━━━━━━━ 49s 2ms/step - loss: 0.0778 - val_loss: 0.0777
# Epoch 3/50
# 20674/20674 ━━━━━━━━━━━━━━━━━━━━ 48s 2ms/step - loss: 0.0774 - val_loss: 0.0775
# Epoch 4/50
# 20674/20674 ━━━━━━━━━━━━━━━━━━━━ 50s 2ms/step - loss: 0.0769 - val_loss: 0.0776
# Epoch 5/50
# 20674/20674 ━━━━━━━━━━━━━━━━━━━━ 49s 2ms/step - loss: 0.0766 - val_loss: 0.0774
# Epoch 6/50
# ...
